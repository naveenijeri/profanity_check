# %%
from profanity_check import predict,predict_prob

# %%
with open('C:/Users/HP/Desktop/fb_data.txt') as f:
    lines=[]
    for line in f:
        line=line.rstrip()
        lines.append(line)

# %%
for l in lines:
    a=predict([l])
    print("number of bad words in sentence: {} , {}".format(l,a))
    b=predict_prob([l])
    print("The ammount of badness in sentence: {},{}".format(l,b))
# Out:
# number of bad words in sentence: hey you are mad , [0]
# The ammount of badness in sentence: hey you are mad,[0.21431816]
# number of bad words in sentence: i want to fuck you , [1]
# The ammount of badness in sentence: i want to fuck you,[0.85967008]
# number of bad words in sentence: i am good boy , [0]
# The ammount of badness in sentence: i am good boy,[0.10829529]
# number of bad words in sentence: Hey You are slut , [0]
# The ammount of badness in sentence: Hey You are slut,[0.3089639]
# number of bad words in sentence: Drug Runners and  a U.S. Senator have something to do with the Murder http://www.amazon.com/Circumstantial-Evidence-Getting-Florida-Bozarth-ebook/dp/B004FPZ452/ref=pd_rhf_p_t_1 The State Attorney Knows... NOW So Will You. GET Ypur Copy TODAY , [0]
# ...
